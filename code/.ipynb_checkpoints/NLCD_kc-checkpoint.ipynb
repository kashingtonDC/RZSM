# %%
import os
import ee
import pandas as pd
import geopandas as gp
import numpy as np
import matplotlib.pyplot as plt

ee.Initialize()

# %%
shp = gp.read_file("../shape/cv.shp")

# %%
shp.plot()

# %%
lls = shp.simplify(0.0009).geometry.iloc[0]

# %%
x,y = lls.exterior.coords.xy

# %%
coords = [list(zip(x,y))]

# %%
area = ee.Geometry.Polygon(coords)

# %%
nlcd11 = ee.Image("USGS/NLCD/NLCD2011")
nlcd01 = ee.Image("USGS/NLCD/NLCD2001")
nlcd06 = ee.Image("USGS/NLCD/NLCD2006")
cdl = ee.Image("USDA/NASS/CDL/2016")

# %%
def img_to_arr(eeImage, var_name):
    temp = eeImage.select(var_name).clip(area)
    latlon = eeImage.pixelLonLat().addBands(temp)
    
    latlon = latlon.reduceRegion(
        reducer = ee.Reducer.toList(),
        geometry = area, 
        scale = 1000
        )
    
    data = np.array((ee.Array(latlon.get(var_name)).getInfo()))
    lats = np.array((ee.Array(latlon.get('latitude')).getInfo()))
    lons = np.array((ee.Array(latlon.get('longitude')).getInfo()))
    
    lc,freq = np.unique(data,return_counts = True)
    
    return data, lats,lons 

def imc_to_arr(eeImage):
    temp = eeImage.filterBounds(area).first().pixelLonLat()
    
    latlon = temp.reduceRegion(
        reducer = ee.Reducer.toList(),
        geometry = area, 
        scale = 1000
        )
    
    data = np.array((ee.Array(latlon.get('cropland')).getInfo()))
    lats = np.array((ee.Array(latlon.get('latitude')).getInfo()))
    lons = np.array((ee.Array(latlon.get('longitude')).getInfo()))
    
    lc,freq = np.unique(data,return_counts = True)
    
    return data, lats,lons 

def test(eeImage):    
    latlon = ee.Dictionary(
      eeImage.reduceRegion(ee.Reducer.frequencyHistogram(), area, 1000).get("cropland")
    );
    
    return latlon

def arr_to_img(data,lats,lons):
    uniquelats = np.unique(lats)
    uniquelons = np.unique(lons)
    
    ncols = len(uniquelons)
    nrows = len(uniquelats)
    
    ys = uniquelats[1] - uniquelats[0]
    xs = uniquelons[1] - uniquelons[0]
    
    arr = np.zeros([nrows, ncols], np.float32)
    
    counter = 0
    for y in range(0, len(arr),1):
        for x in range(0, len(arr[0]),1):
            if lats[counter] == uniquelats[y] and lons[counter] == uniquelons[x] and counter < len(lats)-1:
                counter+=1
                arr[len(uniquelats)-1-y,x] = data[counter]
                
    return arr

# %%
# CDL
data = test(cdl)

# NLCD11
# data, lats, lons = img_to_arr(nlcd01, 'landcover')

# %%
cdl = ee.Image("USDA/NASS/CDL/2008")
t = cdl.reduceRegion(ee.Reducer.frequencyHistogram(), area, 300).get('cropland')

# %%
t.getInfo()
# Out:
# {'1': 11987.0,
#  '111': 7086.172549019607,
#  '12': 200.0,
#  '121': 18740.61960784314,
#  '122': 8151.803921568628,
#  '123': 19372.850980392155,
#  '124': 3065.2588235294115,
#  '13': 6.0,
#  '131': 3792.4352941176467,
#  '141': 588.956862745098,
#  '142': 136.10588235294117,
#  '143': 117.3294117647059,
#  '152': 9402.250980392162,
#  '176': 158520.77647058666,
#  '190': 1803.858823529412,
#  '195': 6905.509803921568,
#  '2': 13224.843137254902,
#  '204': 11277.325490196079,
#  '205': 234.0,
#  '206': 769.0156862745098,
#  '208': 659.0,
#  '209': 831.0,
#  '21': 923.8392156862745,
#  '211': 2151.0117647058823,
#  '212': 8531.611764705882,
#  '213': 347.0,
#  '214': 75.0,
#  '216': 42.0,
#  '217': 1031.8117647058823,
#  '218': 210.0,
#  '219': 4.0,
#  '22': 1711.0,
#  '220': 5426.349019607843,
#  '221': 1.0,
#  '222': 34.0,
#  '223': 3.0,
#  '224': 169.95294117647057,
#  '225': 11846.0,
#  '226': 7786.078431372549,
#  '227': 551.0,
#  '229': 55.0,
#  '23': 26.0,
#  '236': 1168.0,
#  '237': 21.0,
#  '238': 12.0,
#  '24': 23015.603921568632,
#  '242': 2.0,
#  '245': 1.0,
#  '247': 1.0,
#  '27': 211.0,
#  '28': 4769.937254901962,
#  '3': 26276.160784313728,
#  '33': 5769.607843137255,
#  '36': 43430.10196078431,
#  '37': 2091.2509803921566,
#  '4': 154.0,
#  '41': 15.0,
#  '42': 445.0,
#  '43': 104.0,
#  '44': 656.9058823529411,
#  '46': 346.0,
#  '47': 5.0,
#  '48': 351.0,
#  '49': 1164.0,
#  '50': 163.0,
#  '53': 34.0,
#  '54': 10301.0,
#  '57': 75.0,
#  '58': 2430.607843137255,
#  '59': 187.0,
#  '6': 557.0,
#  '61': 43385.57254901964,
#  '66': 945.5294117647059,
#  '67': 555.356862745098,
#  '68': 163.0,
#  '69': 29341.196078431374,
#  '71': 201.0,
#  '72': 231.45882352941177,
#  '74': 19.0,
#  '75': 49652.0274509804,
#  '76': 13634.30980392157,
#  '77': 267.0,
#  '92': 2.0}

# %%
img = arr_to_img(data,lats,lons)

# %%
img[img == 0] = np.nan
plt.figure(figsize=(15,10))
plt.title("CDL2016")
plt.axis("off")
plt.imshow(img)
plt.show()

# %% [markdown]
# <img src="https://i.stack.imgur.com/7sOWc.jpg" width="200" height="200" />

# %%
vals, counts = np.unique(img,return_counts = True)

# %%
plt.hist(img.ravel(),100,[0,300],  lw=2, edgecolor = 'black'); 
plt.ylabel("count")
plt.xlabel('landcover class')
plt.show()

# %%
vals, counts
# Out:
# (array([ 1.,  2.,  3., ..., nan, nan, nan], dtype=float32),
#  array([ 876, 1314, 3303, ...,    1,    1,    1]))

# %%
vals[~np.isnan(vals)]
# Out:
# array([  1.,   2.,   3.,   4.,   6.,  12.,  13.,  21.,  22.,  23.,  24.,
#         27.,  28.,  31.,  33.,  36.,  37.,  41.,  42.,  43.,  44.,  46.,
#         48.,  49.,  50.,  53.,  54.,  57.,  58.,  59.,  61.,  66.,  67.,
#         68.,  69.,  71.,  72.,  74.,  75.,  76.,  77., 111., 121., 122.,
#        123., 124., 131., 141., 142., 152., 176., 190., 195., 204., 205.,
#        206., 208., 209., 211., 212., 213., 214., 216., 217., 218., 220.,
#        222., 224., 225., 226., 227., 229., 236., 237., 238.],
#       dtype=float32)

# %%
Crop_id	Description
1	Water
2	Urban
3	Native classes
4	Orchards, groves, and vineyards
5	Pasture/Hay
6	Row Crops
7	Small Grains
8	Idle/fallow
9	Truck, nursery, and berry crops
10	Citrus and subtropical
11	Field crops
12	Vineyards
13	Pasture
14	Grain and hay crops
15	Semiagricultural (livestock feedlots, diaries, poultry farms)
16	Deciduous fruits and nuts
17	Rice
18	Cotton
19	Developed
20	Cropland and pasture
21	Cropland
22	Irrigated Row and Field Crops
# Out:
#   File "<ipython-input-227-2b4c5e78fb58>", line 1
#     Crop_id	Description
#            	          ^
# SyntaxError: invalid syntax
